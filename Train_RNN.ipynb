# %%
# Mount Google Drive is faster than uploading data. Move repository into Google Drive and update path at end of this section
from google.colab import drive
drive.mount('/content/gdrive') # Don't Update
# Import packages
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(541)
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras, random
random.set_seed(541)
import numpy as np
# Import helper functions from pre_processing.py:
import sys
import os
sys.path.append('/content/gdrive/My Drive/RNN_GRF_Prediction/')  # or '/content/gdrive/My Drive/PATH/TO/REPOSITORY/'
directory = '/content/gdrive/My Drive/RNN_GRF_Prediction/data/'
from pre_processing import *

directory = '/content/gdrive/My Drive/RNN_GRF_Prediction/data/'  # or '/content/gdrive/My Drive/PATH/TO/REPOSITORY/'
# Out:
# Mounted at /content/gdrive

# %%
## Load data ----
fs = 500  # Sampling Frequency

# Accelerometer Data
X = pd.read_csv(os.path.join(directory, 'Accelerometer.csv'), header=None).values
# Subject and Condition Data
Sub_Info = pd.read_csv(os.path.join(directory, 'Sub_Info.csv'))
# Normal GRF data
y = pd.read_csv(os.path.join(directory, 'GRF.csv'), header=None).values

## Train/Test Split ----
train_X = X[(Sub_Info['Slope'] != -5) | (Sub_Info['Slope'] != 5),:]
train_y = y[(Sub_Info['Slope'] != -5) | (Sub_Info['Slope'] != 5),:]
train_Sub_Info = Sub_Info.loc[(Sub_Info['Slope'] != -5) | (Sub_Info['Slope'] != 5),:]
train_Sub_Info.reset_index(drop=True, inplace=True)

test_X = X[(Sub_Info['Slope'] == -5) | (Sub_Info['Slope'] == 5),:]
test_y = y[(Sub_Info['Slope'] == -5) | (Sub_Info['Slope'] == 5),:]
test_Sub_Info = Sub_Info.loc[(Sub_Info['Slope'] == -5) | (Sub_Info['Slope'] == 5),:]
test_Sub_Info.reset_index(drop=True, inplace=True)

## Scale Features ----
l = 2480  # Accelerometer data is concatenated
train_X_V = train_X[:,0:l]
train_X_AP = train_X[:,l:l*2]
test_X_V = test_X[:,0:l]
test_X_AP = test_X[:,l:l*2]

# Sub_Info
train_Sub_Feats = train_Sub_Info[['Height', 'Mass', 'Speed', 'Slope']]
test_Sub_Feats = test_Sub_Info[['Height', 'Mass', 'Speed', 'Slope']]
scaler_sub = MinMaxScaler()
train_Sub_Feats = pd.DataFrame(scaler_sub.fit_transform(train_Sub_Feats))
test_Sub_Feats = pd.DataFrame(scaler_sub.transform(test_Sub_Feats))
train_Sub_Feats.columns = ['Height', 'Mass', 'Speed', 'Slope']
test_Sub_Feats.columns = ['Height', 'Mass', 'Speed', 'Slope']

#Don't include foot strike percentages in min/max scaler because they're 
#already scaled to each other. min/max scaler is per feature (column).
train_Sub_Feats[['RFS', 'MFS', 'FFS']] = train_Sub_Info[['RFS', 'MFS', 'FFS']].copy()/100
test_Sub_Feats[['RFS', 'MFS', 'FFS']] = test_Sub_Info[['RFS', 'MFS', 'FFS']].copy()/100

# Copy over Subject ID
train_Sub_Feats['Sub'] = train_Sub_Info['Sub']
test_Sub_Feats['Sub'] = train_Sub_Info['Sub'][0]
sub_num = 2

## Split accelerometer data into overlapping windows for RNN ----
# N-frame windows centered on prediction frame. Pad w/ nearest value ----
window_size = 6  # 6 frames @ 500 Hz == 12 ms

train_X_V = window_data_centered(train_X_V, window_size, verbose=False)
train_X_AP = window_data_centered(train_X_AP, window_size, verbose=False)
train_y = np.reshape(train_y, (train_y.shape[0],train_y.shape[1],1))

test_X_V = window_data_centered(test_X_V, window_size, verbose=False)
test_X_AP = window_data_centered(test_X_AP, window_size, verbose=False)
test_y = np.reshape(test_y, (test_y.shape[0],test_y.shape[1],1))

# %%
## Generate Features ----
# Calculates mean, sd, range in each window of accelerometer data. generate_features() can also reshape sub_info to match dimensions.
train_feats_V = generate_features(train_X_V, fs, train_Sub_Feats, -sub_num, include_sub_info_feats=False)  # Just signal feats
train_feats_AP = generate_features(train_X_AP, fs, train_Sub_Feats, -sub_num, include_sub_info_feats=True)  # Signal and Sub_Info feats
sub_info_feats = train_feats_AP[-7:-1].copy()
test_feats_V = generate_features(test_X_V, fs, test_Sub_Feats, -sub_num, include_sub_info_feats=False)  # Just signal feats
test_feats_AP = generate_features(test_X_AP, fs, test_Sub_Feats, -sub_num, include_sub_info_feats=True)  # Signal and Sub_Info feats

train_sub_info_feats = train_feats_AP[:,:,-7:].copy()
train_feats_AP = train_feats_AP[:,:,0:3].copy()

test_sub_info_feats = test_feats_AP[:,:,-7:].copy()
test_feats_AP = test_feats_AP[:,:,0:3].copy()

# #remove footstrike features if that's not your thing
# train_sub_info_feats = train_sub_info_feats[:,:,0:4]
# test_sub_info_feats = test_sub_info_feats[:,:,0:4]

def max_scale_3d(feats, train_max):
  feats_scaled = feats / train_max
  return feats_scaled

train_feats_V_scaled = max_scale_3d(train_feats_V, np.max(train_feats_V, axis=(0,1)))
train_feats_AP_scaled = max_scale_3d(train_feats_AP, np.max(train_feats_AP, axis=(0,1)))

test_feats_V_scaled = max_scale_3d(test_feats_V, np.max(train_feats_V, axis=(0,1)))
test_feats_AP_scaled = max_scale_3d(test_feats_AP, np.max(train_feats_AP, axis=(0,1)))

train_feats = np.concatenate((train_feats_V_scaled, train_feats_AP_scaled, train_sub_info_feats), axis = 2)
test_feats = np.concatenate((test_feats_V_scaled, test_feats_AP_scaled, test_sub_info_feats), axis = 2)

print('TRAINING DATA: \nNumber of trials: %d \nNumber of overlapping windows: %d \nNumber of features per window: %d' % train_feats.shape)
print('\nTESTING DATA: \nNumber of trials: %d \nNumber of overlapping windows: %d \nNumber of features per window: %d' % test_feats.shape)
# Out:
# TRAINING DATA:
# Number of trials: 31
# Number of overlapping windows: 2480
# Number of features per window: 13
#
# TESTING DATA:
# Number of trials: 13
# Number of overlapping windows: 2480
# Number of features per window: 13

# %%
## Construct Model ----
def build_model(lr=0.001, loss='mean_squared_error'):

  #accelerometer data lstm model
  accel_inputs = keras.Input(shape=(None,train_feats.shape[2]))  # Shape is number of features. Undefined number of windows
  accel_features = keras.layers.Dropout(0.2, seed=541,)(accel_inputs)
  accel_features = keras.layers.Bidirectional(keras.layers.LSTM(512, activation='tanh', return_sequences=True), merge_mode='ave')(accel_features)
  accel_features = keras.layers.Dropout(0.4, seed=541)(accel_features)
  accel_features = keras.layers.Dense(128, activation='relu')(accel_features)
  accel_features = keras.layers.Dense(384, activation='relu')(accel_features)
  accel_features = keras.layers.Dense(320, activation='relu')(accel_features)
  accel_outputs = keras.layers.Dense(1, activation='linear')(accel_features)

  model_out = keras.Model(inputs=accel_inputs, outputs=accel_outputs, name='Accel_subcond_LSTM')
  # define optimizer algorithm and learning rate
  opt = keras.optimizers.Adam(learning_rate =lr)
  # compile model and define loss function
  model_out.compile(optimizer=opt, loss=loss)

  return model_out

# Build Model
model = build_model()

# Plot Model
# keras.utils.plot_model(model, show_shapes=True, show_layer_names=False)

# %%
# Train Model ----
# Make sure you're using the GPU runtime type!

# Define Early Stopping and Checkpoint Callbacks
model_filename = '/content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5'
data_filename =  '/content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Data.pkl'
# early stopping
es = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                  mode='min', 
                                  verbose=0, 
                                  patience=30, 
                                  min_delta=0.001, 
                                  restore_best_weights=True
                                  )

# model checkpoint
mc = keras.callbacks.ModelCheckpoint(
    model_filename,
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    save_best_only=True, 
    save_weights_only=False
    )

# Fit Model
history_accel = model.fit(
    train_feats, 
    train_y, 
    epochs=1000,
    validation_data=(test_feats, test_y), 
    verbose=1,
    batch_size=32, 
    callbacks=[es, mc]
    )

# Plot Train/Validation Loss across epochs
plt.plot(history_accel.history['loss'], label = 'mse_train')
plt.plot(history_accel.history['val_loss'], label = 'mse_validation')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 1.5385 - val_loss: 0.9845
#
# Epoch 00001: val_loss improved from inf to 0.98447, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 2/1000
# 1/1 [==============================] - 1s 783ms/step - loss: 0.9696 - val_loss: 3.5587
#
# Epoch 00002: val_loss did not improve from 0.98447
# Epoch 3/1000
# 1/1 [==============================] - 1s 784ms/step - loss: 3.6304 - val_loss: 0.7713
#
# Epoch 00003: val_loss improved from 0.98447 to 0.77127, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 4/1000
# 1/1 [==============================] - 1s 791ms/step - loss: 0.7601 - val_loss: 1.0377
#
# Epoch 00004: val_loss did not improve from 0.77127
# Epoch 5/1000
# 1/1 [==============================] - 1s 788ms/step - loss: 1.0141 - val_loss: 1.1949
#
# Epoch 00005: val_loss did not improve from 0.77127
# Epoch 6/1000
# 1/1 [==============================] - 1s 811ms/step - loss: 1.1574 - val_loss: 1.2632
#
# Epoch 00006: val_loss did not improve from 0.77127
# Epoch 7/1000
# 1/1 [==============================] - 1s 802ms/step - loss: 1.2227 - val_loss: 1.2777
#
# Epoch 00007: val_loss did not improve from 0.77127
# Epoch 8/1000
# 1/1 [==============================] - 1s 808ms/step - loss: 1.2337 - val_loss: 1.2500
#
# Epoch 00008: val_loss did not improve from 0.77127
# Epoch 9/1000
# 1/1 [==============================] - 1s 814ms/step - loss: 1.2053 - val_loss: 1.1789
#
# Epoch 00009: val_loss did not improve from 0.77127
# Epoch 10/1000
# 1/1 [==============================] - 1s 802ms/step - loss: 1.1396 - val_loss: 1.0549
#
# Epoch 00010: val_loss did not improve from 0.77127
# Epoch 11/1000
# 1/1 [==============================] - 1s 795ms/step - loss: 1.0230 - val_loss: 0.8679
#
# Epoch 00011: val_loss did not improve from 0.77127
# Epoch 12/1000
# 1/1 [==============================] - 1s 806ms/step - loss: 0.8546 - val_loss: 0.6843
#
# Epoch 00012: val_loss improved from 0.77127 to 0.68432, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 13/1000
# 1/1 [==============================] - 1s 817ms/step - loss: 0.7031 - val_loss: 1.0046
#
# Epoch 00013: val_loss did not improve from 0.68432
# Epoch 14/1000
# 1/1 [==============================] - 1s 809ms/step - loss: 0.9747 - val_loss: 0.6510
#
# Epoch 00014: val_loss improved from 0.68432 to 0.65098, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 15/1000
# 1/1 [==============================] - 1s 808ms/step - loss: 0.6569 - val_loss: 0.6450
#
# Epoch 00015: val_loss improved from 0.65098 to 0.64503, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 16/1000
# 1/1 [==============================] - 1s 802ms/step - loss: 0.6435 - val_loss: 0.6612
#
# Epoch 00016: val_loss did not improve from 0.64503
# Epoch 17/1000
# 1/1 [==============================] - 1s 801ms/step - loss: 0.6631 - val_loss: 0.6590
#
# Epoch 00017: val_loss did not improve from 0.64503
# Epoch 18/1000
# 1/1 [==============================] - 1s 813ms/step - loss: 0.6623 - val_loss: 0.6369
#
# Epoch 00018: val_loss improved from 0.64503 to 0.63692, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 19/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.6417 - val_loss: 0.6011
#
# Epoch 00019: val_loss improved from 0.63692 to 0.60112, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 20/1000
# 1/1 [==============================] - 1s 810ms/step - loss: 0.6068 - val_loss: 0.5630
#
# Epoch 00020: val_loss improved from 0.60112 to 0.56297, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 21/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.5690 - val_loss: 0.5393
#
# Epoch 00021: val_loss improved from 0.56297 to 0.53928, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 22/1000
# 1/1 [==============================] - 1s 813ms/step - loss: 0.5437 - val_loss: 0.5126
#
# Epoch 00022: val_loss improved from 0.53928 to 0.51264, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 23/1000
# 1/1 [==============================] - 1s 809ms/step - loss: 0.5144 - val_loss: 0.4522
#
# Epoch 00023: val_loss improved from 0.51264 to 0.45222, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 24/1000
# 1/1 [==============================] - 1s 812ms/step - loss: 0.4552 - val_loss: 0.4014
#
# Epoch 00024: val_loss improved from 0.45222 to 0.40136, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 25/1000
# 1/1 [==============================] - 1s 844ms/step - loss: 0.4110 - val_loss: 0.3408
#
# Epoch 00025: val_loss improved from 0.40136 to 0.34083, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 26/1000
# 1/1 [==============================] - 1s 818ms/step - loss: 0.3566 - val_loss: 0.2466
#
# Epoch 00026: val_loss improved from 0.34083 to 0.24659, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 27/1000
# 1/1 [==============================] - 1s 812ms/step - loss: 0.2667 - val_loss: 0.4187
#
# Epoch 00027: val_loss did not improve from 0.24659
# Epoch 28/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.4249 - val_loss: 0.4863
#
# Epoch 00028: val_loss did not improve from 0.24659
# Epoch 29/1000
# 1/1 [==============================] - 1s 814ms/step - loss: 0.4734 - val_loss: 0.6574
#
# Epoch 00029: val_loss did not improve from 0.24659
# Epoch 30/1000
# 1/1 [==============================] - 1s 809ms/step - loss: 0.6191 - val_loss: 0.6301
#
# Epoch 00030: val_loss did not improve from 0.24659
# Epoch 31/1000
# 1/1 [==============================] - 1s 816ms/step - loss: 0.5845 - val_loss: 0.4207
#
# Epoch 00031: val_loss did not improve from 0.24659
# Epoch 32/1000
# 1/1 [==============================] - 1s 820ms/step - loss: 0.3957 - val_loss: 0.4987
#
# Epoch 00032: val_loss did not improve from 0.24659
# Epoch 33/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.5890 - val_loss: 0.2495
#
# Epoch 00033: val_loss did not improve from 0.24659
# Epoch 34/1000
# 1/1 [==============================] - 1s 818ms/step - loss: 0.2616 - val_loss: 0.3081
#
# Epoch 00034: val_loss did not improve from 0.24659
# Epoch 35/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.3147 - val_loss: 0.3191
#
# Epoch 00035: val_loss did not improve from 0.24659
# Epoch 36/1000
# 1/1 [==============================] - 1s 814ms/step - loss: 0.3309 - val_loss: 0.2978
#
# Epoch 00036: val_loss did not improve from 0.24659
# Epoch 37/1000
# 1/1 [==============================] - 1s 820ms/step - loss: 0.3151 - val_loss: 0.2700
#
# Epoch 00037: val_loss did not improve from 0.24659
# Epoch 38/1000
# 1/1 [==============================] - 1s 826ms/step - loss: 0.2865 - val_loss: 0.2577
#
# Epoch 00038: val_loss did not improve from 0.24659
# Epoch 39/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.2744 - val_loss: 0.2675
#
# Epoch 00039: val_loss did not improve from 0.24659
# Epoch 40/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.2848 - val_loss: 0.2765
#
# Epoch 00040: val_loss did not improve from 0.24659
# Epoch 41/1000
# 1/1 [==============================] - 1s 820ms/step - loss: 0.2902 - val_loss: 0.2515
#
# Epoch 00041: val_loss did not improve from 0.24659
# Epoch 42/1000
# 1/1 [==============================] - 1s 817ms/step - loss: 0.2706 - val_loss: 0.1986
#
# Epoch 00042: val_loss improved from 0.24659 to 0.19857, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 43/1000
# 1/1 [==============================] - 1s 821ms/step - loss: 0.2281 - val_loss: 0.1558
#
# Epoch 00043: val_loss improved from 0.19857 to 0.15581, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 44/1000
# 1/1 [==============================] - 1s 815ms/step - loss: 0.1889 - val_loss: 0.1441
#
# Epoch 00044: val_loss improved from 0.15581 to 0.14407, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 45/1000
# 1/1 [==============================] - 1s 824ms/step - loss: 0.1786 - val_loss: 0.1503
#
# Epoch 00045: val_loss did not improve from 0.14407
# Epoch 46/1000
# 1/1 [==============================] - 1s 819ms/step - loss: 0.1796 - val_loss: 0.1503
#
# Epoch 00046: val_loss did not improve from 0.14407
# Epoch 47/1000
# 1/1 [==============================] - 1s 824ms/step - loss: 0.1744 - val_loss: 0.1342
#
# Epoch 00047: val_loss improved from 0.14407 to 0.13417, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 48/1000
# 1/1 [==============================] - 1s 825ms/step - loss: 0.1554 - val_loss: 0.1152
#
# Epoch 00048: val_loss improved from 0.13417 to 0.11517, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 49/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.1505 - val_loss: 0.1139
#
# Epoch 00049: val_loss improved from 0.11517 to 0.11393, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 50/1000
# 1/1 [==============================] - 1s 824ms/step - loss: 0.1584 - val_loss: 0.1192
#
# Epoch 00050: val_loss did not improve from 0.11393
# Epoch 51/1000
# 1/1 [==============================] - 1s 832ms/step - loss: 0.1757 - val_loss: 0.1088
#
# Epoch 00051: val_loss improved from 0.11393 to 0.10877, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 52/1000
# 1/1 [==============================] - 1s 823ms/step - loss: 0.1541 - val_loss: 0.1018
#
# Epoch 00052: val_loss improved from 0.10877 to 0.10181, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 53/1000
# 1/1 [==============================] - 1s 843ms/step - loss: 0.1328 - val_loss: 0.1036
#
# Epoch 00053: val_loss did not improve from 0.10181
# Epoch 54/1000
# 1/1 [==============================] - 1s 831ms/step - loss: 0.1341 - val_loss: 0.0974
#
# Epoch 00054: val_loss improved from 0.10181 to 0.09741, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 55/1000
# 1/1 [==============================] - 1s 828ms/step - loss: 0.1274 - val_loss: 0.0807
#
# Epoch 00055: val_loss improved from 0.09741 to 0.08073, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 56/1000
# 1/1 [==============================] - 1s 826ms/step - loss: 0.1166 - val_loss: 0.0668
#
# Epoch 00056: val_loss improved from 0.08073 to 0.06684, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 57/1000
# 1/1 [==============================] - 1s 818ms/step - loss: 0.1038 - val_loss: 0.0674
#
# Epoch 00057: val_loss did not improve from 0.06684
# Epoch 58/1000
# 1/1 [==============================] - 1s 836ms/step - loss: 0.1018 - val_loss: 0.0746
#
# Epoch 00058: val_loss did not improve from 0.06684
# Epoch 59/1000
# 1/1 [==============================] - 1s 830ms/step - loss: 0.1056 - val_loss: 0.0717
#
# Epoch 00059: val_loss did not improve from 0.06684
# Epoch 60/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0993 - val_loss: 0.0623
#
# Epoch 00060: val_loss improved from 0.06684 to 0.06225, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 61/1000
# 1/1 [==============================] - 1s 836ms/step - loss: 0.0920 - val_loss: 0.0577
#
# Epoch 00061: val_loss improved from 0.06225 to 0.05770, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 62/1000
# 1/1 [==============================] - 1s 827ms/step - loss: 0.0902 - val_loss: 0.0566
#
# Epoch 00062: val_loss improved from 0.05770 to 0.05659, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 63/1000
# 1/1 [==============================] - 1s 833ms/step - loss: 0.0887 - val_loss: 0.0522
#
# Epoch 00063: val_loss improved from 0.05659 to 0.05222, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 64/1000
# 1/1 [==============================] - 1s 835ms/step - loss: 0.0837 - val_loss: 0.0454
#
# Epoch 00064: val_loss improved from 0.05222 to 0.04536, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 65/1000
# 1/1 [==============================] - 1s 830ms/step - loss: 0.0737 - val_loss: 0.0432
#
# Epoch 00065: val_loss improved from 0.04536 to 0.04325, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 66/1000
# 1/1 [==============================] - 1s 832ms/step - loss: 0.0725 - val_loss: 0.0450
#
# Epoch 00066: val_loss did not improve from 0.04325
# Epoch 67/1000
# 1/1 [==============================] - 1s 840ms/step - loss: 0.0731 - val_loss: 0.0397
#
# Epoch 00067: val_loss improved from 0.04325 to 0.03970, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 68/1000
# 1/1 [==============================] - 1s 826ms/step - loss: 0.0685 - val_loss: 0.0343
#
# Epoch 00068: val_loss improved from 0.03970 to 0.03431, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 69/1000
# 1/1 [==============================] - 1s 838ms/step - loss: 0.0612 - val_loss: 0.0360
#
# Epoch 00069: val_loss did not improve from 0.03431
# Epoch 70/1000
# 1/1 [==============================] - 1s 840ms/step - loss: 0.0643 - val_loss: 0.0352
#
# Epoch 00070: val_loss did not improve from 0.03431
# Epoch 71/1000
# 1/1 [==============================] - 1s 843ms/step - loss: 0.0613 - val_loss: 0.0307
#
# Epoch 00071: val_loss improved from 0.03431 to 0.03069, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 72/1000
# 1/1 [==============================] - 1s 830ms/step - loss: 0.0551 - val_loss: 0.0302
#
# Epoch 00072: val_loss improved from 0.03069 to 0.03024, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 73/1000
# 1/1 [==============================] - 1s 850ms/step - loss: 0.0567 - val_loss: 0.0293
#
# Epoch 00073: val_loss improved from 0.03024 to 0.02926, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 74/1000
# 1/1 [==============================] - 1s 834ms/step - loss: 0.0536 - val_loss: 0.0269
#
# Epoch 00074: val_loss improved from 0.02926 to 0.02691, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 75/1000
# 1/1 [==============================] - 1s 833ms/step - loss: 0.0496 - val_loss: 0.0282
#
# Epoch 00075: val_loss did not improve from 0.02691
# Epoch 76/1000
# 1/1 [==============================] - 1s 842ms/step - loss: 0.0526 - val_loss: 0.0279
#
# Epoch 00076: val_loss did not improve from 0.02691
# Epoch 77/1000
# 1/1 [==============================] - 1s 847ms/step - loss: 0.0491 - val_loss: 0.0297
#
# Epoch 00077: val_loss did not improve from 0.02691
# Epoch 78/1000
# 1/1 [==============================] - 1s 842ms/step - loss: 0.0498 - val_loss: 0.0304
#
# Epoch 00078: val_loss did not improve from 0.02691
# Epoch 79/1000
# 1/1 [==============================] - 1s 841ms/step - loss: 0.0497 - val_loss: 0.0282
#
# Epoch 00079: val_loss did not improve from 0.02691
# Epoch 80/1000
# 1/1 [==============================] - 1s 849ms/step - loss: 0.0483 - val_loss: 0.0277
#
# Epoch 00080: val_loss did not improve from 0.02691
# Epoch 81/1000
# 1/1 [==============================] - 1s 844ms/step - loss: 0.0491 - val_loss: 0.0259
#
# Epoch 00081: val_loss improved from 0.02691 to 0.02590, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 82/1000
# 1/1 [==============================] - 1s 840ms/step - loss: 0.0464 - val_loss: 0.0260
#
# Epoch 00082: val_loss did not improve from 0.02590
# Epoch 83/1000
# 1/1 [==============================] - 1s 848ms/step - loss: 0.0460 - val_loss: 0.0236
#
# Epoch 00083: val_loss improved from 0.02590 to 0.02360, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 84/1000
# 1/1 [==============================] - 1s 852ms/step - loss: 0.0460 - val_loss: 0.0250
#
# Epoch 00084: val_loss did not improve from 0.02360
# Epoch 85/1000
# 1/1 [==============================] - 1s 850ms/step - loss: 0.0463 - val_loss: 0.0233
#
# Epoch 00085: val_loss improved from 0.02360 to 0.02333, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 86/1000
# 1/1 [==============================] - 1s 845ms/step - loss: 0.0445 - val_loss: 0.0232
#
# Epoch 00086: val_loss improved from 0.02333 to 0.02324, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 87/1000
# 1/1 [==============================] - 1s 841ms/step - loss: 0.0446 - val_loss: 0.0230
#
# Epoch 00087: val_loss improved from 0.02324 to 0.02299, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 88/1000
# 1/1 [==============================] - 1s 842ms/step - loss: 0.0434 - val_loss: 0.0228
#
# Epoch 00088: val_loss improved from 0.02299 to 0.02283, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 89/1000
# 1/1 [==============================] - 1s 845ms/step - loss: 0.0420 - val_loss: 0.0237
#
# Epoch 00089: val_loss did not improve from 0.02283
# Epoch 90/1000
# 1/1 [==============================] - 1s 851ms/step - loss: 0.0431 - val_loss: 0.0221
#
# Epoch 00090: val_loss improved from 0.02283 to 0.02208, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 91/1000
# 1/1 [==============================] - 1s 854ms/step - loss: 0.0409 - val_loss: 0.0234
#
# Epoch 00091: val_loss did not improve from 0.02208
# Epoch 92/1000
# 1/1 [==============================] - 1s 855ms/step - loss: 0.0414 - val_loss: 0.0223
#
# Epoch 00092: val_loss did not improve from 0.02208
# Epoch 93/1000
# 1/1 [==============================] - 1s 856ms/step - loss: 0.0406 - val_loss: 0.0216
#
# Epoch 00093: val_loss improved from 0.02208 to 0.02158, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 94/1000
# 1/1 [==============================] - 1s 853ms/step - loss: 0.0401 - val_loss: 0.0217
#
# Epoch 00094: val_loss did not improve from 0.02158
# Epoch 95/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0406 - val_loss: 0.0204
#
# Epoch 00095: val_loss improved from 0.02158 to 0.02041, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 96/1000
# 1/1 [==============================] - 1s 847ms/step - loss: 0.0379 - val_loss: 0.0212
#
# Epoch 00096: val_loss did not improve from 0.02041
# Epoch 97/1000
# 1/1 [==============================] - 1s 853ms/step - loss: 0.0396 - val_loss: 0.0200
#
# Epoch 00097: val_loss improved from 0.02041 to 0.02001, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 98/1000
# 1/1 [==============================] - 1s 860ms/step - loss: 0.0378 - val_loss: 0.0197
#
# Epoch 00098: val_loss improved from 0.02001 to 0.01968, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 99/1000
# 1/1 [==============================] - 1s 863ms/step - loss: 0.0371 - val_loss: 0.0197
#
# Epoch 00099: val_loss improved from 0.01968 to 0.01967, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 100/1000
# 1/1 [==============================] - 1s 846ms/step - loss: 0.0367 - val_loss: 0.0193
#
# Epoch 00100: val_loss improved from 0.01967 to 0.01931, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 101/1000
# 1/1 [==============================] - 1s 860ms/step - loss: 0.0350 - val_loss: 0.0195
#
# Epoch 00101: val_loss did not improve from 0.01931
# Epoch 102/1000
# 1/1 [==============================] - 1s 855ms/step - loss: 0.0364 - val_loss: 0.0186
#
# Epoch 00102: val_loss improved from 0.01931 to 0.01860, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 103/1000
# 1/1 [==============================] - 1s 850ms/step - loss: 0.0360 - val_loss: 0.0183
#
# Epoch 00103: val_loss improved from 0.01860 to 0.01828, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 104/1000
# 1/1 [==============================] - 1s 866ms/step - loss: 0.0354 - val_loss: 0.0176
#
# Epoch 00104: val_loss improved from 0.01828 to 0.01760, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 105/1000
# 1/1 [==============================] - 1s 865ms/step - loss: 0.0344 - val_loss: 0.0173
#
# Epoch 00105: val_loss improved from 0.01760 to 0.01731, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 106/1000
# 1/1 [==============================] - 1s 854ms/step - loss: 0.0352 - val_loss: 0.0172
#
# Epoch 00106: val_loss improved from 0.01731 to 0.01722, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 107/1000
# 1/1 [==============================] - 1s 855ms/step - loss: 0.0351 - val_loss: 0.0166
#
# Epoch 00107: val_loss improved from 0.01722 to 0.01661, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 108/1000
# 1/1 [==============================] - 1s 861ms/step - loss: 0.0324 - val_loss: 0.0169
#
# Epoch 00108: val_loss did not improve from 0.01661
# Epoch 109/1000
# 1/1 [==============================] - 1s 868ms/step - loss: 0.0336 - val_loss: 0.0154
#
# Epoch 00109: val_loss improved from 0.01661 to 0.01539, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 110/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0326 - val_loss: 0.0157
#
# Epoch 00110: val_loss did not improve from 0.01539
# Epoch 111/1000
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0327 - val_loss: 0.0146
#
# Epoch 00111: val_loss improved from 0.01539 to 0.01462, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 112/1000
# 1/1 [==============================] - 1s 869ms/step - loss: 0.0326 - val_loss: 0.0146
#
# Epoch 00112: val_loss did not improve from 0.01462
# Epoch 113/1000
# 1/1 [==============================] - 1s 880ms/step - loss: 0.0322 - val_loss: 0.0144
#
# Epoch 00113: val_loss improved from 0.01462 to 0.01440, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 114/1000
# 1/1 [==============================] - 1s 858ms/step - loss: 0.0307 - val_loss: 0.0150
#
# Epoch 00114: val_loss did not improve from 0.01440
# Epoch 115/1000
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0316 - val_loss: 0.0141
#
# Epoch 00115: val_loss improved from 0.01440 to 0.01409, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 116/1000
# 1/1 [==============================] - 1s 863ms/step - loss: 0.0303 - val_loss: 0.0143
#
# Epoch 00116: val_loss did not improve from 0.01409
# Epoch 117/1000
# 1/1 [==============================] - 1s 872ms/step - loss: 0.0298 - val_loss: 0.0138
#
# Epoch 00117: val_loss improved from 0.01409 to 0.01377, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 118/1000
# 1/1 [==============================] - 1s 869ms/step - loss: 0.0302 - val_loss: 0.0137
#
# Epoch 00118: val_loss improved from 0.01377 to 0.01370, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 119/1000
# 1/1 [==============================] - 1s 863ms/step - loss: 0.0289 - val_loss: 0.0136
#
# Epoch 00119: val_loss improved from 0.01370 to 0.01362, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 120/1000
# 1/1 [==============================] - 1s 878ms/step - loss: 0.0299 - val_loss: 0.0137
#
# Epoch 00120: val_loss did not improve from 0.01362
# Epoch 121/1000
# 1/1 [==============================] - 1s 860ms/step - loss: 0.0291 - val_loss: 0.0135
#
# Epoch 00121: val_loss improved from 0.01362 to 0.01354, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 122/1000
# 1/1 [==============================] - 1s 868ms/step - loss: 0.0291 - val_loss: 0.0138
#
# Epoch 00122: val_loss did not improve from 0.01354
# Epoch 123/1000
# 1/1 [==============================] - 1s 883ms/step - loss: 0.0283 - val_loss: 0.0138
#
# Epoch 00123: val_loss did not improve from 0.01354
# Epoch 124/1000
# 1/1 [==============================] - 1s 868ms/step - loss: 0.0279 - val_loss: 0.0139
#
# Epoch 00124: val_loss did not improve from 0.01354
# Epoch 125/1000
# 1/1 [==============================] - 1s 885ms/step - loss: 0.0284 - val_loss: 0.0131
#
# Epoch 00125: val_loss improved from 0.01354 to 0.01314, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 126/1000
# 1/1 [==============================] - 1s 867ms/step - loss: 0.0280 - val_loss: 0.0128
#
# Epoch 00126: val_loss improved from 0.01314 to 0.01283, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 127/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0279 - val_loss: 0.0130
#
# Epoch 00127: val_loss did not improve from 0.01283
# Epoch 128/1000
# 1/1 [==============================] - 1s 873ms/step - loss: 0.0282 - val_loss: 0.0128
#
# Epoch 00128: val_loss improved from 0.01283 to 0.01278, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 129/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0276 - val_loss: 0.0128
#
# Epoch 00129: val_loss did not improve from 0.01278
# Epoch 130/1000
# 1/1 [==============================] - 1s 878ms/step - loss: 0.0277 - val_loss: 0.0129
#
# Epoch 00130: val_loss did not improve from 0.01278
# Epoch 131/1000
# 1/1 [==============================] - 1s 879ms/step - loss: 0.0270 - val_loss: 0.0130
#
# Epoch 00131: val_loss did not improve from 0.01278
# Epoch 132/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0270 - val_loss: 0.0127
#
# Epoch 00132: val_loss improved from 0.01278 to 0.01271, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 133/1000
# 1/1 [==============================] - 1s 874ms/step - loss: 0.0268 - val_loss: 0.0124
#
# Epoch 00133: val_loss improved from 0.01271 to 0.01238, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 134/1000
# 1/1 [==============================] - 1s 878ms/step - loss: 0.0269 - val_loss: 0.0123
#
# Epoch 00134: val_loss improved from 0.01238 to 0.01233, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 135/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0265 - val_loss: 0.0124
#
# Epoch 00135: val_loss did not improve from 0.01233
# Epoch 136/1000
# 1/1 [==============================] - 1s 881ms/step - loss: 0.0251 - val_loss: 0.0128
#
# Epoch 00136: val_loss did not improve from 0.01233
# Epoch 137/1000
# 1/1 [==============================] - 1s 874ms/step - loss: 0.0261 - val_loss: 0.0128
#
# Epoch 00137: val_loss did not improve from 0.01233
# Epoch 138/1000
# 1/1 [==============================] - 1s 883ms/step - loss: 0.0259 - val_loss: 0.0123
#
# Epoch 00138: val_loss improved from 0.01233 to 0.01226, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 139/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0264 - val_loss: 0.0122
#
# Epoch 00139: val_loss improved from 0.01226 to 0.01218, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 140/1000
# 1/1 [==============================] - 1s 882ms/step - loss: 0.0248 - val_loss: 0.0126
#
# Epoch 00140: val_loss did not improve from 0.01218
# Epoch 141/1000
# 1/1 [==============================] - 1s 882ms/step - loss: 0.0252 - val_loss: 0.0121
#
# Epoch 00141: val_loss improved from 0.01218 to 0.01210, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 142/1000
# 1/1 [==============================] - 1s 883ms/step - loss: 0.0263 - val_loss: 0.0123
#
# Epoch 00142: val_loss did not improve from 0.01210
# Epoch 143/1000
# 1/1 [==============================] - 1s 875ms/step - loss: 0.0249 - val_loss: 0.0125
#
# Epoch 00143: val_loss did not improve from 0.01210
# Epoch 144/1000
# 1/1 [==============================] - 1s 881ms/step - loss: 0.0249 - val_loss: 0.0125
#
# Epoch 00144: val_loss did not improve from 0.01210
# Epoch 145/1000
# 1/1 [==============================] - 1s 870ms/step - loss: 0.0259 - val_loss: 0.0117
#
# Epoch 00145: val_loss improved from 0.01210 to 0.01168, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 146/1000
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0252 - val_loss: 0.0118
#
# Epoch 00146: val_loss did not improve from 0.01168
# Epoch 147/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0244 - val_loss: 0.0131
#
# Epoch 00147: val_loss did not improve from 0.01168
# Epoch 148/1000
# 1/1 [==============================] - 1s 878ms/step - loss: 0.0263 - val_loss: 0.0125
#
# Epoch 00148: val_loss did not improve from 0.01168
# Epoch 149/1000
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0240 - val_loss: 0.0119
#
# Epoch 00149: val_loss did not improve from 0.01168
# Epoch 150/1000
# 1/1 [==============================] - 1s 875ms/step - loss: 0.0238 - val_loss: 0.0116
#
# Epoch 00150: val_loss improved from 0.01168 to 0.01157, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 151/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0241 - val_loss: 0.0128
#
# Epoch 00151: val_loss did not improve from 0.01157
# Epoch 152/1000
# 1/1 [==============================] - 1s 874ms/step - loss: 0.0239 - val_loss: 0.0119
#
# Epoch 00152: val_loss did not improve from 0.01157
# Epoch 153/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0230 - val_loss: 0.0116
#
# Epoch 00153: val_loss improved from 0.01157 to 0.01156, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 154/1000
# 1/1 [==============================] - 1s 873ms/step - loss: 0.0234 - val_loss: 0.0120
#
# Epoch 00154: val_loss did not improve from 0.01156
# Epoch 155/1000
# 1/1 [==============================] - 1s 884ms/step - loss: 0.0221 - val_loss: 0.0123
#
# Epoch 00155: val_loss did not improve from 0.01156
# Epoch 156/1000
# 1/1 [==============================] - 1s 881ms/step - loss: 0.0240 - val_loss: 0.0112
#
# Epoch 00156: val_loss improved from 0.01156 to 0.01118, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 157/1000
# 1/1 [==============================] - 1s 872ms/step - loss: 0.0232 - val_loss: 0.0110
#
# Epoch 00157: val_loss improved from 0.01118 to 0.01098, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 158/1000
# 1/1 [==============================] - 1s 884ms/step - loss: 0.0225 - val_loss: 0.0119
#
# Epoch 00158: val_loss did not improve from 0.01098
# Epoch 159/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0226 - val_loss: 0.0117
#
# Epoch 00159: val_loss did not improve from 0.01098
# Epoch 160/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0223 - val_loss: 0.0116
#
# Epoch 00160: val_loss did not improve from 0.01098
# Epoch 161/1000
# 1/1 [==============================] - 1s 860ms/step - loss: 0.0223 - val_loss: 0.0113
#
# Epoch 00161: val_loss did not improve from 0.01098
# Epoch 162/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0219 - val_loss: 0.0112
#
# Epoch 00162: val_loss did not improve from 0.01098
# Epoch 163/1000
# 1/1 [==============================] - 1s 869ms/step - loss: 0.0224 - val_loss: 0.0113
#
# Epoch 00163: val_loss did not improve from 0.01098
# Epoch 164/1000
# 1/1 [==============================] - 1s 880ms/step - loss: 0.0218 - val_loss: 0.0113
#
# Epoch 00164: val_loss did not improve from 0.01098
# Epoch 165/1000
# 1/1 [==============================] - 1s 874ms/step - loss: 0.0219 - val_loss: 0.0110
#
# Epoch 00165: val_loss did not improve from 0.01098
# Epoch 166/1000
# 1/1 [==============================] - 1s 868ms/step - loss: 0.0218 - val_loss: 0.0121
#
# Epoch 00166: val_loss did not improve from 0.01098
# Epoch 167/1000
# 1/1 [==============================] - 1s 855ms/step - loss: 0.0212 - val_loss: 0.0113
#
# Epoch 00167: val_loss did not improve from 0.01098
# Epoch 168/1000
# 1/1 [==============================] - 1s 872ms/step - loss: 0.0214 - val_loss: 0.0106
#
# Epoch 00168: val_loss improved from 0.01098 to 0.01064, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 169/1000
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0212 - val_loss: 0.0113
#
# Epoch 00169: val_loss did not improve from 0.01064
# Epoch 170/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0211 - val_loss: 0.0125
#
# Epoch 00170: val_loss did not improve from 0.01064
# Epoch 171/1000
# 1/1 [==============================] - 1s 861ms/step - loss: 0.0221 - val_loss: 0.0111
#
# Epoch 00171: val_loss did not improve from 0.01064
# Epoch 172/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0218 - val_loss: 0.0108
#
# Epoch 00172: val_loss did not improve from 0.01064
# Epoch 173/1000
# 1/1 [==============================] - 1s 866ms/step - loss: 0.0210 - val_loss: 0.0112
#
# Epoch 00173: val_loss did not improve from 0.01064
# Epoch 174/1000
# 1/1 [==============================] - 1s 869ms/step - loss: 0.0211 - val_loss: 0.0113
#
# Epoch 00174: val_loss did not improve from 0.01064
# Epoch 175/1000
# 1/1 [==============================] - 1s 861ms/step - loss: 0.0208 - val_loss: 0.0109
#
# Epoch 00175: val_loss did not improve from 0.01064
# Epoch 176/1000
# 1/1 [==============================] - 1s 874ms/step - loss: 0.0202 - val_loss: 0.0119
#
# Epoch 00176: val_loss did not improve from 0.01064
# Epoch 177/1000
# 1/1 [==============================] - 1s 859ms/step - loss: 0.0207 - val_loss: 0.0110
#
# Epoch 00177: val_loss did not improve from 0.01064
# Epoch 178/1000
# 1/1 [==============================] - 1s 856ms/step - loss: 0.0209 - val_loss: 0.0101
#
# Epoch 00178: val_loss improved from 0.01064 to 0.01009, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 179/1000
# 1/1 [==============================] - 1s 865ms/step - loss: 0.0204 - val_loss: 0.0118
#
# Epoch 00179: val_loss did not improve from 0.01009
# Epoch 180/1000
# 1/1 [==============================] - 1s 870ms/step - loss: 0.0204 - val_loss: 0.0115
#
# Epoch 00180: val_loss did not improve from 0.01009
# Epoch 181/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0200 - val_loss: 0.0110
#
# Epoch 00181: val_loss did not improve from 0.01009
# Epoch 182/1000
# 1/1 [==============================] - 1s 867ms/step - loss: 0.0202 - val_loss: 0.0117
#
# Epoch 00182: val_loss did not improve from 0.01009
# Epoch 183/1000
# 1/1 [==============================] - 1s 859ms/step - loss: 0.0202 - val_loss: 0.0114
#
# Epoch 00183: val_loss did not improve from 0.01009
# Epoch 184/1000
# 1/1 [==============================] - 1s 875ms/step - loss: 0.0201 - val_loss: 0.0103
#
# Epoch 00184: val_loss did not improve from 0.01009
# Epoch 185/1000
# 1/1 [==============================] - 1s 877ms/step - loss: 0.0202 - val_loss: 0.0108
#
# Epoch 00185: val_loss did not improve from 0.01009
# Epoch 186/1000
# 1/1 [==============================] - 1s 879ms/step - loss: 0.0203 - val_loss: 0.0116
#
# Epoch 00186: val_loss did not improve from 0.01009
# Epoch 187/1000
# 1/1 [==============================] - 1s 871ms/step - loss: 0.0196 - val_loss: 0.0117
#
# Epoch 00187: val_loss did not improve from 0.01009
# Epoch 188/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0196 - val_loss: 0.0106
#
# Epoch 00188: val_loss did not improve from 0.01009
# Epoch 189/1000
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0193 - val_loss: 0.0102
#
# Epoch 00189: val_loss did not improve from 0.01009
# Epoch 190/1000
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0197 - val_loss: 0.0112
#
# Epoch 00190: val_loss did not improve from 0.01009
# Epoch 191/1000
# 1/1 [==============================] - 1s 876ms/step - loss: 0.0185 - val_loss: 0.0112
#
# Epoch 00191: val_loss did not improve from 0.01009
# Epoch 192/1000
# 1/1 [==============================] - 1s 870ms/step - loss: 0.0189 - val_loss: 0.0104
#
# Epoch 00192: val_loss did not improve from 0.01009
# Epoch 193/1000
# 1/1 [==============================] - 1s 867ms/step - loss: 0.0187 - val_loss: 0.0108
#
# Epoch 00193: val_loss did not improve from 0.01009
# Epoch 194/1000
# 1/1 [==============================] - 1s 868ms/step - loss: 0.0190 - val_loss: 0.0103
#
# Epoch 00194: val_loss did not improve from 0.01009
# Epoch 195/1000
# 1/1 [==============================] - 1s 873ms/step - loss: 0.0186 - val_loss: 0.0099
#
# Epoch 00195: val_loss improved from 0.01009 to 0.00994, saving model to /content/gdrive/My Drive/Research/Uphill_Downhill/code_repo/updownhill_running/data/Model.h5
# Epoch 196/1000
# 1/1 [==============================] - 1s 873ms/step - loss: 0.0187 - val_loss: 0.0113
#
# Epoch 00196: val_loss did not improve from 0.00994
# Epoch 197/1000
# 1/1 [==============================] - 1s 865ms/step - loss: 0.0185 - val_loss: 0.0116
#
# Epoch 00197: val_loss did not improve from 0.00994
# Epoch 198/1000
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0185 - val_loss: 0.0100
#
# Epoch 00198: val_loss did not improve from 0.00994

# %%
## Load Best Model ----
saved_model = keras.models.load_model(model_filename)

test_scores = saved_model.evaluate(test_feats, test_y, verbose = 2)
pred_final = saved_model.predict(test_feats)
pred_final = np.squeeze(pred_final)

# Plot Prediction vs Measured GRF ----
i = 0 # trial to plot
s = 500  # frame to start plot
e = 1000  # frame to end plot
fig, ax = plt.subplots(1,1, figsize=(10,5))
ax.plot(test_y[i,s:e], '-', label='true')
ax.plot(pred_final[i,s:e], 'r--', label='prediction')
ax.grid()
ax.set_title(' Speed: ' + str(test_Sub_Info['Speed'].iloc[i]) + 
             ' Slope: ' + str(test_Sub_Info['Slope'].iloc[i])
             )
print()
plt.show()
# Out:
# 1/1 - 1s - loss: 0.0099

# %%
## Get Info about Saved Model ----
saved_model.summary()
# saved_model.get_config()
# Out:
# Model: "Accel_subcond_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 13)]        0
# _________________________________________________________________
# dropout (Dropout)            (None, None, 13)          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 512)         2154496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 512)         0
# _________________________________________________________________
# dense (Dense)                (None, None, 128)         65664
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 384)         49536
# _________________________________________________________________
# dense_2 (Dense)              (None, None, 320)         123200
# _________________________________________________________________
# dense_3 (Dense)              (None, None, 1)           321
# =================================================================
# Total params: 2,393,217
# Trainable params: 2,393,217
# Non-trainable params: 0
# _________________________________________________________________
